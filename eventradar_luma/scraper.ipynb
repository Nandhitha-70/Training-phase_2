# %%
# ✅ Step 1: Scraping Events from Luma Bengaluru
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time

# Setup ChromeDriver
chrome_driver_path = "C:\\Users\\nandhu S\\OneDrive\\Desktop\\eventradar_project\\chromedriver.exe"
options = webdriver.ChromeOptions()
options.add_argument("--headless")
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service, options=options)

# Open Luma Bengaluru Page
url = "https://lu.ma/bengaluru"
driver.get(url)
time.sleep(5)

soup = BeautifulSoup(driver.page_source, "lxml")

# Scrape all events
cards = soup.select("a.event-link.content-link")
event_list = []

for card in cards:
    # Get Event URL
    relative_link = card.get("href", "")
    full_link = "https://lu.ma" + relative_link
    
    # Navigate to individual event page
    driver.get(full_link)
    time.sleep(3)
    event_soup = BeautifulSoup(driver.page_source, "lxml")

    # Extract basic fields
    title = event_soup.select_one("h1").text.strip() if event_soup.select_one("h1") else ""
    
    # Extract Date
    date_block = event_soup.find("div", class_="jsx-3191908726 date")
    event_date = date_block.text.strip() if date_block else ""

    # Location Handling
    location_block = event_soup.find("div", string=lambda x: x and "Location" in x)
    location = location_block.find_next("div").text.strip() if location_block else "Online"

    # Description for tag inference
    desc = event_soup.select_one("div.markdown").text.strip() if event_soup.select_one("div.markdown") else ""

    event_list.append({
        "event_title": title,
        "platform": "Luma",
        "topic_tags": "",       # To be filled in Step 3
        "event_type": "Meetup", # Assume Luma Bengaluru = meetups
        "event_date": event_date,
        "location": location,
        "speakers_orgs": "",    # Usually not listed upfront
        "url": full_link,
        "audience_segment": ""  # To be tagged later
    })

# Quit browser
driver.quit()

# Save raw data to CSV
luma_raw_df = pd.DataFrame(event_list)
luma_raw_df.to_csv("01_raw_luma_events.csv", index=False)
luma_raw_df.head()
# Out:
#                                          event_title platform topic_tags  \
# 0  The AI Shift in B2C | From User Experience to ...     Luma
# 1  Agara Walks & Filter Kaapi - All Things Health...     Luma
# 2                                   AI Day Bengaluru     Luma
# 3        VIBE-ATHON: Where AI Meets Firebase Magic ⚡     Luma
# 4                     Build Your Own DailySync Agent     Luma
#
#   event_type event_date  location speakers_orgs                     url  \
# 0     Meetup             Location                https://lu.ma/fqrhf805
# 1     Meetup             Location                https://lu.ma/dbiihmyw
# 2     Meetup             Location                https://lu.ma/acvb1fkb
# 3     Meetup             Location                https://lu.ma/y1arivc5
# 4     Meetup             Location                https://lu.ma/lwl5dh24
#
#   audience_segment
# 0
# 1
# 2
# 3
# 4

# %%
# 🧰 Import libraries
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# 🔧 Set up ChromeDriver path
chrome_path = r"C:\Users\nandhu S\OneDrive\Desktop\eventradar_project\chromedriver.exe"
service = Service(chrome_path)
driver = webdriver.Chrome(service=service)

# 🌐 Load Luma Singapore events page
url = "https://lu.ma/singapore"
driver.get(url)
time.sleep(3)  # Let the page load

# %%
# 🧪 Parse using BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, "lxml")

# 🔍 Find all event links (anchor tags)
event_links = soup.find_all("a", class_="event-link content-link")

print(f"Found {len(event_links)} events")
# 📊 Extract Event Info
base_url = "https://lu.ma"
events = []

for link in event_links:
    try:
        title = link.get("aria-label", "").strip()
        href = base_url + link.get("href", "").strip()
        
        events.append({
            "event_title": title,
            "platform": "Luma",
            "event_type": "",  # To be inferred later
            "event_date": "",  # To be filled later
            "location": "",    # To be filled later
            "url": href,
            "speakers_orgs": "",  # Optional
            "topic_tags": "",     # To be tagged
            "audience_segment": ""  # To be tagged
        })
    except Exception as e:
        print(f"Error: {e}")

import pandas as pd
df_raw = pd.DataFrame(events)
df_raw.to_csv("eventradar_raw_luma.csv", index=False)
df_raw.head()
# Out:
# Found 20 events
#                                          event_title platform event_type  \
# 0       AIGents of Change #4: Media, Authorship & AI     Luma
# 1  Rise & Walk - Saturday June 21st @Henderson Wa...     Luma
# 2           The Saturday Book Club June 2025 Session     Luma
# 3       Women in AI: Idea to working MVP in 2 hours!     Luma
# 4  Conversations on Caregiving: Envisioning the F...     Luma
#
#   event_date location                     url speakers_orgs topic_tags  \
# 0                      https://lu.ma/vynb9gp5
# 1                      https://lu.ma/gk1ezao7
# 2                      https://lu.ma/djifk2z0
# 3                      https://lu.ma/yre3ad0m
# 4                      https://lu.ma/4pxgchp4
#
#   audience_segment
# 0
# 1
# 2
# 3
# 4
